# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

model_dict={1124:"plant1_loc1_24",
            1148:"plant1_loc1_48",
            1224:"plant1_loc2_24",
            1248:"plant1_loc2_48",
            1324:"plant1_loc3_24",
            1348:"plant1_loc3_48",
            2124:"plant2_loc1_24",
            2148:"plant2_loc1_48",
            2224:"plant2_loc2_24",
            2248:"plant2_loc2_48",
            2324:"plant2_loc3_24",
            2348:"plant2_loc3_48" 
           }
"""
plant1 : loc1 24 / 48 , loc2 24 / 48 , loc3 24 / 48
              25   49        26   50        27   51 
plant2 : loc1 24 / 48 , loc2 24 / 48 , loc3 24 / 48
              50   98        52   100       54   102
"""
# Out:
# '\nplant1 : loc1 24 / 48 , loc2 24 / 48 , loc3 24 / 48\n              25   49        26   50        27   51 \nplant2 : loc1 24 / 48 , loc2 24 / 48 , loc3 24 / 48\n              50   98        52   100       54   102\n'

# %%
tree1124 = GaussianNB()
tree1148 = GaussianNB()
tree1224 = GaussianNB()
tree1248 = GaussianNB()
tree1324 = GaussianNB()
tree1348 = GaussianNB()
tree2124 = GaussianNB()
tree2148 = GaussianNB()
tree2224 = GaussianNB()
tree2248 = GaussianNB()
tree2324 = GaussianNB()
tree2348 = GaussianNB()

# %%
import Normalizing

# %%
#validation???
def data_loader(url1, url2):
    data1 = pd.read_csv(url1)
    data2 = pd.read_csv(url2)
    # 쓸데없는 컬럼 삭제 일단 Unnamed
    
    label_24 = ['X24H_cond_loc1','X24H_cond_loc2','X24H_cond_loc3']
    label_48 = ['X48H_cond_loc1','X48H_cond_loc2','X48H_cond_loc3']
    
    feature = ['tem_loc1','hum_loc1','coil_loc1',
               'tem_loc2','hum_loc2','coil_loc2',
               'tem_loc3','hum_loc3','coil_loc3',
               'tem_out','hum_out']
    X1 = Normalizing.normalize(data1, feature)
    X2 = Normalizing.normalize(data2, feature)
    
    X1 = X1[feature]
    X2 = X2[feature]
    
    y_1024 = data1[label_24]
    y_1024 = y_1024.dropna(axis=0)
    y_2024 = data2[label_24]
    y_2024 = y_2024.dropna(axis=0)
    
    X_1024 = X1.iloc[:y_1024.shape[0], :]
    X_2024 = X2.iloc[:y_2024.shape[0], :]
    
    y_1048 = data1[label_48]
    y_1048 = y_1048.dropna(axis=0)
    y_2048 = data2[label_48]
    y_2048 = y_2048.dropna(axis=0)
    
    X_1048 = X1.iloc[:y_1048.shape[0], :]
    X_2048 = X2.iloc[:y_2048.shape[0], :]
    # 행의 개수가 다르기 때문.
    X_1124 = X_1024[['tem_loc1','hum_loc1','coil_loc1','tem_out','hum_out']]
    X_1124.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_1124 = y_1024['X24H_cond_loc1']
    
    X_1148 = X_1048[['tem_loc1','hum_loc1','coil_loc1','tem_out','hum_out']]
    X_1148.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_1148 = y_1048['X48H_cond_loc1']
    
    X_1224 = X_1024[['tem_loc2','hum_loc2','coil_loc2','tem_out','hum_out']]
    X_1224.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_1224 = y_1024['X24H_cond_loc2']
        
    X_1248 = X_1048[['tem_loc2','hum_loc2','coil_loc2','tem_out','hum_out']]
    X_1248.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_1248 = y_1048['X48H_cond_loc2']

        
    X_1324 = X_1024[['tem_loc3','hum_loc3','coil_loc3','tem_out','hum_out']]
    X_1324.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_1324 = y_1024['X24H_cond_loc3']
        
    X_1348 = X_1048[['tem_loc3','hum_loc3','coil_loc3','tem_out','hum_out']]
    X_1348.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_1348 = y_1048['X48H_cond_loc3']

        
    X_2124 = X_2024[['tem_loc1','hum_loc1','coil_loc1','tem_out','hum_out']]
    X_2124.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_2124 = y_2024['X24H_cond_loc1']

    
    X_2148 = X_2048[['tem_loc1','hum_loc1','coil_loc1','tem_out','hum_out']]
    X_2148.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_2148 = y_2048['X48H_cond_loc1']


    X_2224 = X_2024[['tem_loc2','hum_loc2','coil_loc2','tem_out','hum_out']]
    X_2224.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_2224 = y_2024['X24H_cond_loc2']


    X_2248 = X_2048[['tem_loc2','hum_loc2','coil_loc2','tem_out','hum_out']]
    X_2248.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_2248 = y_2048['X48H_cond_loc2']

    
    X_2324 = X_2024[['tem_loc3','hum_loc3','coil_loc3','tem_out','hum_out']]
    X_2324.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_2324 = y_2024['X24H_cond_loc3']

    X_2348 = X_2048[['tem_loc3','hum_loc3','coil_loc3','tem_out','hum_out']]
    X_2348.columns=['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
    y_2348 = y_2048['X48H_cond_loc3']
  
    
 
    tree1124.fit(X_1124, y_1124.values.ravel())
   
    tree1148.fit(X_1148, y_1148.values.ravel())
   
    tree1224.fit(X_1224, y_1224.values.ravel())
   
    tree1248.fit(X_1248, y_1248.values.ravel())
   
    tree1324.fit(X_1324, y_1324.values.ravel())
   
    tree1348.fit(X_1348, y_1348.values.ravel())
 
    tree2124.fit(X_2124, y_2124.values.ravel())
 
    tree2148.fit(X_2148, y_2148.values.ravel())
  
    tree2224.fit(X_2224, y_2224.values.ravel())
 
    tree2248.fit(X_2248, y_2248.values.ravel())
 
    tree2324.fit(X_2324, y_2324.values.ravel())
    
    tree2348.fit(X_2348, y_2348.values.ravel())

# %%
import pandas as pd
def predict_data(url):
    data = pd.read_csv(url)
    vali_data = pd.read_csv('./Source_validation.csv')
    for i in data.index:
        plant = data.loc[i]['plant_test.plant']
        loc = data.loc[i]['plant_test.loc']
        model_24 = int(plant)*1000 + int(loc)*100 + 24
        model_48 = int(plant)*1000 + int(loc)*100 + 48
        
        feature = ['plant_test.tem_in','plant_test.hum_in','plant_test.tem_coil',
                   'plant_test.tem_out_loc1','plant_test.hum_out_loc1']
        
        X_test = data.loc[i, feature]
        X_test.columns = ['tem_in','hum_in','tem_coil','tem_out_loc1','hum_out_loc1']
        
        print(X_test)
        if model_24 == 1124:
            pred24 = tree1124.predict([X_test])
            pred24_proba = tree1124.predict_proba([X_test])
            
        elif model_24 == 2124:
            pred24 = tree2124.predict([X_test])
            pred24_proba = tree2124.predict_proba([X_test])
                
        elif model_24 == 1224:
            pred24 = tree1224.predict([X_test])
            pred24_proba = tree1224.predict_proba([X_test])
            
        elif model_24 == 2224:
            pred24 = tree2224.predict([X_test])
            pred24_proba = tree2224.predict_proba([X_test])
            
        elif model_24 == 1324:
            pred24 = tree1324.predict([X_test])
            pred24_proba = tree1324.predict_proba([X_test])
            
        elif model_24 == 2324:
            pred24 = tree2324.predict([X_test])
            pred24_proba = tree2324.predict_proba([X_test])
            
            
            
        if model_48 == 1148:
            pred48 = tree1148.predict([X_test])
            pred48_proba = tree1148.predict_proba([X_test])
            
        elif model_48 == 2148:
            pred48 = tree2148.predict([X_test])
            pred48_proba = tree2148.predict_proba([X_test])
            
        elif model_48 == 1248:
            pred48 = tree1248.predict([X_test])
            pred48_proba = tree1248.predict_proba([X_test])
            
        elif model_48 == 2248:
            pred48 = tree2248.predict([X_test])
            pred48_proba = tree2248.predict_proba([X_test])
            
        elif model_48 == 1348:
            pred48 = tree1348.predict([X_test])
            pred48_proba = tree1348.predict_proba([X_test])
            
        elif model_48 == 2348:
            pred48 = tree2348.predict([X_test])
            pred48_proba = tree2348.predict_proba([X_test])
        
#         y_test_24 = data['plant_test.x24h_cond_loc']
#         y_test_24.columns = ['x24h_cond']
#         y_test_48 = data['plant_test.x48h_cond_loc']
#         print(data.loc[i]['plant_test.x24h_tma'])
#         print(vali_data.loc[i])
        vali_data['X24H_COND_LOC'][i] = pred24[0]
        vali_data['X48H_COND_LOC'][i] = pred48[0]
        vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
        vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
        
#         print("plant : "+str(plant)+" loc : "+str(loc))
#         print(pred24, pred48)
#         print(pred24_proba, pred48_proba)
#         print()
    vali_data.to_csv('./validation_predict_normalize_naive.csv')

# %%
plant1_train = './plant1_teasoung_test.csv'
plant2_train = './plant2_teasoung_test.csv'
data_loader(plant1_train, plant2_train)

# %%
test = './Source_plant_test.csv'
predict_data(test)
# Out:
# plant_test.tem_in           8.17
# plant_test.hum_in          40.42
# plant_test.tem_coil         10.1
# plant_test.tem_out_loc1      4.2
# plant_test.hum_out_loc1    54.82
# Name: 0, dtype: object
# plant_test.tem_in          10.03
# plant_test.hum_in          48.81
# plant_test.tem_coil        10.79
# plant_test.tem_out_loc1     6.09
# plant_test.hum_out_loc1    59.34
# Name: 1, dtype: object
# plant_test.tem_in           9.45
# plant_test.hum_in          40.93
# plant_test.tem_coil         9.07
# plant_test.tem_out_loc1    12.26
# plant_test.hum_out_loc1    32.14
# Name: 2, dtype: object
# plant_test.tem_in          12.32
# plant_test.hum_in          34.13
# plant_test.tem_coil        10.86
# plant_test.tem_out_loc1    12.32
# plant_test.hum_out_loc1    28.27
# Name: 3, dtype: object
# plant_test.tem_in          11.28
# plant_test.hum_in          22.65
# plant_test.tem_coil         8.76
# plant_test.tem_out_loc1    12.01
# plant_test.hum_out_loc1    19.84
# Name: 4, dtype: object
# plant_test.tem_in          12.26
# plant_test.hum_in          25.46
# plant_test.tem_coil         9.45
# plant_test.tem_out_loc1     9.66
# plant_test.hum_out_loc1    29.52
# Name: 5, dtype: object
# plant_test.tem_in          11.62
# plant_test.hum_in          25.55
# plant_test.tem_coil         9.45
# plant_test.tem_out_loc1     7.99
# plant_test.hum_out_loc1    31.81
# Name: 6, dtype: object
# plant_test.tem_in          10.06
# plant_test.hum_in          30.59
# plant_test.tem_coil         8.92
# plant_test.tem_out_loc1     5.15
# plant_test.hum_out_loc1    42.28
# Name: 7, dtype: object
# plant_test.tem_in           7.34
# plant_test.hum_in          46.98
# plant_test.tem_coil        10.33
# plant_test.tem_out_loc1     1.36
# plant_test.hum_out_loc1    64.53
# Name: 8, dtype: object
# plant_test.tem_in           9.27
# plant_test.hum_in          42.77
# plant_test.tem_coil         9.76
# plant_test.tem_out_loc1     3.68
# plant_test.hum_out_loc1    64.01
# Name: 9, dtype: object
# plant_test.tem_in          10.55
# plant_test.hum_in          51.86
# plant_test.tem_coil        10.06
# plant_test.tem_out_loc1    13.39
# plant_test.hum_out_loc1    41.36
# Name: 10, dtype: object
# plant_test.tem_in          12.26
# plant_test.hum_in          29.98
# plant_test.tem_coil        10.79
# plant_test.tem_out_loc1    10.37
# plant_test.hum_out_loc1    27.23
# Name: 11, dtype: object
# plant_test.tem_in          13.66
# plant_test.hum_in          22.59
# plant_test.tem_coil        11.17
# plant_test.tem_out_loc1    10.06
# plant_test.hum_out_loc1    22.13
# Name: 12, dtype: object
# plant_test.tem_in          12.72
# plant_test.hum_in          26.19
# plant_test.tem_coil         8.95
# plant_test.tem_out_loc1    10.89
# plant_test.hum_out_loc1    21.49
# Name: 13, dtype: object
# plant_test.tem_in          13.85
# plant_test.hum_in          22.59
# plant_test.tem_coil        11.28
# plant_test.tem_out_loc1    10.18
# plant_test.hum_out_loc1       25
# Name: 14, dtype: object
# plant_test.tem_in          12.66
# plant_test.hum_in          22.59
# plant_test.tem_coil         8.88
# plant_test.tem_out_loc1    10.49
# plant_test.hum_out_loc1    20.21
# Name: 15, dtype: object
# plant_test.tem_in          12.75
# plant_test.hum_in          27.75
# plant_test.tem_coil        11.43
# plant_test.tem_out_loc1     8.44
# plant_test.hum_out_loc1     35.5
# Name: 16, dtype: object
# plant_test.tem_in           9.76
# plant_test.hum_in          44.35
# plant_test.tem_coil        10.79
# plant_test.tem_out_loc1     3.71
# plant_test.hum_out_loc1    66.54
# Name: 17, dtype: object
# plant_test.tem_in          11.28
# plant_test.hum_in          38.71
# plant_test.tem_coil        10.79
# plant_test.tem_out_loc1     3.65
# plant_test.hum_out_loc1    61.02
# Name: 18, dtype: object
# plant_test.tem_in           8.08
# plant_test.hum_in          44.11
# plant_test.tem_coil         8.61
# plant_test.tem_out_loc1     2.98
# plant_test.hum_out_loc1    67.52
# Name: 19, dtype: object
# plant_test.tem_in           10.4
# plant_test.hum_in          42.83
# plant_test.tem_coil        10.37
# plant_test.tem_out_loc1     1.36
# plant_test.hum_out_loc1    70.36
# Name: 20, dtype: object
# plant_test.tem_in           7.25
# plant_test.hum_in          51.16
# plant_test.tem_coil         6.89
# plant_test.tem_out_loc1     4.78
# plant_test.hum_out_loc1    62.64
# Name: 21, dtype: object
# plant_test.tem_in           8.38
# plant_test.hum_in          50.15
# plant_test.tem_coil         7.47
# plant_test.tem_out_loc1    14.98
# plant_test.hum_out_loc1    35.41
# Name: 22, dtype: object
# plant_test.tem_in           10.4
# plant_test.hum_in          46.28
# plant_test.tem_coil         10.1
# plant_test.tem_out_loc1    12.32
# plant_test.hum_out_loc1     39.1
# Name: 23, dtype: object
# plant_test.tem_in           9.79
# plant_test.hum_in          48.72
# plant_test.tem_coil         7.96
# plant_test.tem_out_loc1    19.04
# plant_test.hum_out_loc1    26.37
# Name: 24, dtype: object
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# plant_test.tem_in          11.71
# plant_test.hum_in          44.02
# plant_test.tem_coil         8.84
# plant_test.tem_out_loc1    20.47
# plant_test.hum_out_loc1    23.41
# Name: 25, dtype: object
# plant_test.tem_in          12.14
# plant_test.hum_in          43.53
# plant_test.tem_coil        10.33
# plant_test.tem_out_loc1    12.08
# plant_test.hum_out_loc1    39.96
# Name: 26, dtype: object
# plant_test.tem_in          12.63
# plant_test.hum_in          47.31
# plant_test.tem_coil         9.37
# plant_test.tem_out_loc1    11.43
# plant_test.hum_out_loc1    50.15
# Name: 27, dtype: object
# plant_test.tem_in          13.36
# plant_test.hum_in           34.1
# plant_test.tem_coil          9.3
# plant_test.tem_out_loc1    10.52
# plant_test.hum_out_loc1    34.16
# Name: 28, dtype: object
# plant_test.tem_in          12.17
# plant_test.hum_in          31.44
# plant_test.tem_coil        10.02
# plant_test.tem_out_loc1     8.11
# plant_test.hum_out_loc1     38.4
# Name: 29, dtype: object
# plant_test.tem_in          11.07
# plant_test.hum_in          31.93
# plant_test.tem_coil         9.11
# plant_test.tem_out_loc1     7.37
# plant_test.hum_out_loc1    42.16
# Name: 30, dtype: object
# plant_test.tem_in           9.11
# plant_test.hum_in          39.62
# plant_test.tem_coil        10.37
# plant_test.tem_out_loc1     4.05
# plant_test.hum_out_loc1    53.91
# Name: 31, dtype: object
# plant_test.tem_in            8.2
# plant_test.hum_in          52.32
# plant_test.tem_coil         7.43
# plant_test.tem_out_loc1      2.8
# plant_test.hum_out_loc1     82.6
# Name: 32, dtype: object
# plant_test.tem_in           7.74
# plant_test.hum_in          57.97
# plant_test.tem_coil         9.57
# plant_test.tem_out_loc1     2.74
# plant_test.hum_out_loc1    85.01
# Name: 33, dtype: object
# plant_test.tem_in           9.63
# plant_test.hum_in          49.69
# plant_test.tem_coil         10.1
# plant_test.tem_out_loc1     1.88
# plant_test.hum_out_loc1    81.47
# Name: 34, dtype: object
# plant_test.tem_in          13.94
# plant_test.hum_in          34.95
# plant_test.tem_coil        10.63
# plant_test.tem_out_loc1    16.68
# plant_test.hum_out_loc1    23.53
# Name: 35, dtype: object
# plant_test.tem_in          14.24
# plant_test.hum_in           29.3
# plant_test.tem_coil        11.28
# plant_test.tem_out_loc1     12.2
# plant_test.hum_out_loc1    37.15
# Name: 36, dtype: object
# plant_test.tem_in          13.63
# plant_test.hum_in          40.35
# plant_test.tem_coil        11.93
# plant_test.tem_out_loc1     6.95
# plant_test.hum_out_loc1    63.55
# Name: 37, dtype: object
# plant_test.tem_in          13.05
# plant_test.hum_in          45.15
# plant_test.tem_coil         11.7
# plant_test.tem_out_loc1     6.67
# plant_test.hum_out_loc1    67.28
# Name: 38, dtype: object
# plant_test.tem_in          10.09
# plant_test.hum_in          52.35
# plant_test.tem_coil         9.45
# plant_test.tem_out_loc1     7.86
# plant_test.hum_out_loc1    65.14
# Name: 39, dtype: object
# plant_test.tem_in          12.66
# plant_test.hum_in          46.52
# plant_test.tem_coil        11.43
# plant_test.tem_out_loc1     7.25
# plant_test.hum_out_loc1    60.87
# Name: 40, dtype: object
# plant_test.tem_in          10.52
# plant_test.hum_in          57.11
# plant_test.tem_coil         9.91
# plant_test.tem_out_loc1     7.77
# plant_test.hum_out_loc1    76.89
# Name: 41, dtype: object
# plant_test.tem_in          10.85
# plant_test.hum_in          56.75
# plant_test.tem_coil        10.75
# plant_test.tem_out_loc1     7.68
# plant_test.hum_out_loc1    72.41
# Name: 42, dtype: object
# plant_test.tem_in          10.46
# plant_test.hum_in          58.61
# plant_test.tem_coil        10.33
# plant_test.tem_out_loc1     7.44
# plant_test.hum_out_loc1    71.06
# Name: 43, dtype: object
# plant_test.tem_in          10.12
# plant_test.hum_in          71.34
# plant_test.tem_coil         9.11
# plant_test.tem_out_loc1     8.69
# plant_test.hum_out_loc1    86.66
# Name: 44, dtype: object
# plant_test.tem_in          10.76
# plant_test.hum_in          74.21
# plant_test.tem_coil         9.91
# plant_test.tem_out_loc1     9.57
# plant_test.hum_out_loc1    89.44
# Name: 45, dtype: object
# plant_test.tem_in          11.95
# plant_test.hum_in          72.31
# plant_test.tem_coil        10.63
# plant_test.tem_out_loc1    10.34
# plant_test.hum_out_loc1    78.08
# Name: 46, dtype: object
# plant_test.tem_in          14.73
# plant_test.hum_in          41.79
# plant_test.tem_coil         11.4
# plant_test.tem_out_loc1    16.78
# plant_test.hum_out_loc1    31.59
# Name: 47, dtype: object
# plant_test.tem_in          16.75
# plant_test.hum_in          30.46
# plant_test.tem_coil        11.93
# plant_test.tem_out_loc1    14.79
# plant_test.hum_out_loc1    25.21
# Name: 48, dtype: object
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# <ipython-input-12-483f9fa5482d>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC'][i] = pred24[0]
# <ipython-input-12-483f9fa5482d>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC'][i] = pred48[0]
# <ipython-input-12-483f9fa5482d>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X24H_COND_LOC_PROB'][i] = pred24_proba[0][int(pred24[0])]*100
# <ipython-input-12-483f9fa5482d>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vali_data['X48H_COND_LOC_PROB'][i] = pred48_proba[0][int(pred48[0])]*100
# plant_test.tem_in          28.01
# plant_test.hum_in           47.5
# plant_test.tem_coil        28.26
# plant_test.tem_out_loc1    23.83
# plant_test.hum_out_loc1    62.52
# Name: 873, dtype: object
# plant_test.tem_in          26.73
# plant_test.hum_in          53.27
# plant_test.tem_coil        27.42
# plant_test.tem_out_loc1    23.16
# plant_test.hum_out_loc1    66.27
# Name: 874, dtype: object
# plant_test.tem_in          27.12
# plant_test.hum_in          51.16
# plant_test.tem_coil        27.19
# plant_test.tem_out_loc1    24.74
# plant_test.hum_out_loc1    53.57
# Name: 875, dtype: object
# plant_test.tem_in          27.58
# plant_test.hum_in          50.09
# plant_test.tem_coil        27.23
# plant_test.tem_out_loc1     27.8
# plant_test.hum_out_loc1    46.15
# Name: 876, dtype: object
# plant_test.tem_in          28.32
# plant_test.hum_in          47.22
# plant_test.tem_coil        27.35
# plant_test.tem_out_loc1    28.77
# plant_test.hum_out_loc1    43.28
# Name: 877, dtype: object
# plant_test.tem_in           29.6
# plant_test.hum_in          41.27
# plant_test.tem_coil        28.91
# plant_test.tem_out_loc1    32.56
# plant_test.hum_out_loc1    33.79
# Name: 878, dtype: object
# plant_test.tem_in          30.42
# plant_test.hum_in          38.28
# plant_test.tem_coil        27.77
# plant_test.tem_out_loc1    30.85
# plant_test.hum_out_loc1    33.09
# Name: 879, dtype: object
# plant_test.tem_in          31.03
# plant_test.hum_in          36.23
# plant_test.tem_coil        29.37
# plant_test.tem_out_loc1    31.89
# plant_test.hum_out_loc1    33.09
# Name: 880, dtype: object
# plant_test.tem_in          31.03
# plant_test.hum_in          37.12
# plant_test.tem_coil        28.99
# plant_test.tem_out_loc1    30.24
# plant_test.hum_out_loc1    43.04
# Name: 881, dtype: object
# plant_test.tem_in           30.3
# plant_test.hum_in           43.5
# plant_test.tem_coil        28.11
# plant_test.tem_out_loc1    27.95
# plant_test.hum_out_loc1    46.98
# Name: 882, dtype: object
# plant_test.tem_in          30.57
# plant_test.hum_in           45.7
# plant_test.tem_coil         28.8
# plant_test.tem_out_loc1    26.85
# plant_test.hum_out_loc1    52.11
# Name: 883, dtype: object
# plant_test.tem_in          28.04
# plant_test.hum_in          40.35
# plant_test.tem_coil        28.07
# plant_test.tem_out_loc1    24.68
# plant_test.hum_out_loc1    46.37
# Name: 884, dtype: object
# plant_test.tem_in          27.89
# plant_test.hum_in          41.54
# plant_test.tem_coil        28.15
# plant_test.tem_out_loc1     24.1
# plant_test.hum_out_loc1    48.66
# Name: 885, dtype: object
# plant_test.tem_in          27.95
# plant_test.hum_in           39.9
# plant_test.tem_coil        27.99
# plant_test.tem_out_loc1    23.03
# plant_test.hum_out_loc1    50.03
# Name: 886, dtype: object
# plant_test.tem_in          27.52
# plant_test.hum_in          41.73
# plant_test.tem_coil        27.84
# plant_test.tem_out_loc1       22
# plant_test.hum_out_loc1    53.85
# Name: 887, dtype: object
# plant_test.tem_in          28.35
# plant_test.hum_in          41.39
# plant_test.tem_coil        27.88
# plant_test.tem_out_loc1    27.34
# plant_test.hum_out_loc1    39.29
# Name: 888, dtype: object
# plant_test.tem_in           27.7
# plant_test.hum_in             41
# plant_test.tem_coil        27.54
# plant_test.tem_out_loc1    28.19
# plant_test.hum_out_loc1    36.81
# Name: 889, dtype: object
# plant_test.tem_in          26.94
# plant_test.hum_in          44.26
# plant_test.tem_coil        27.08
# plant_test.tem_out_loc1    28.86
# plant_test.hum_out_loc1    36.32
# Name: 890, dtype: object
# plant_test.tem_in          29.23
# plant_test.hum_in          39.26
# plant_test.tem_coil        28.11
# plant_test.tem_out_loc1    29.72
# plant_test.hum_out_loc1    36.54
# Name: 891, dtype: object
# plant_test.tem_in          30.05
# plant_test.hum_in          38.86
# plant_test.tem_coil         28.3
# plant_test.tem_out_loc1    27.98
# plant_test.hum_out_loc1    40.42
# Name: 892, dtype: object
# plant_test.tem_in          30.91
# plant_test.hum_in          40.45
# plant_test.tem_coil        28.95
# plant_test.tem_out_loc1    28.19
# plant_test.hum_out_loc1    47.62
# Name: 893, dtype: object
# plant_test.tem_in          29.99
# plant_test.hum_in          45.67
# plant_test.tem_coil        29.22
# plant_test.tem_out_loc1    25.81
# plant_test.hum_out_loc1    61.42
# Name: 894, dtype: object
# plant_test.tem_in          27.31
# plant_test.hum_in          47.83
# plant_test.tem_coil        27.38
# plant_test.tem_out_loc1    25.32
# plant_test.hum_out_loc1    49.97
# Name: 895, dtype: object
# plant_test.tem_in          26.39
# plant_test.hum_in          46.92
# plant_test.tem_coil         28.3
# plant_test.tem_out_loc1    22.15
# plant_test.hum_out_loc1    61.66
# Name: 896, dtype: object
# plant_test.tem_in          29.81
# plant_test.hum_in           38.4
# plant_test.tem_coil        27.84
# plant_test.tem_out_loc1     29.2
# plant_test.hum_out_loc1    35.84
# Name: 897, dtype: object
# plant_test.tem_in          28.99
# plant_test.hum_in          41.39
# plant_test.tem_coil        27.42
# plant_test.tem_out_loc1     29.2
# plant_test.hum_out_loc1    35.84
# Name: 898, dtype: object
# plant_test.tem_in          30.48
# plant_test.hum_in          38.58
# plant_test.tem_coil        28.61
# plant_test.tem_out_loc1     29.2
# plant_test.hum_out_loc1    35.84
# Name: 899, dtype: object
# plant_test.tem_in          30.94
# plant_test.hum_in          35.93
# plant_test.tem_coil        29.94
# plant_test.tem_out_loc1    30.36
# plant_test.hum_out_loc1    36.54
# Name: 900, dtype: object
# plant_test.tem_in          30.54
# plant_test.hum_in          36.54
# plant_test.tem_coil        29.94
# plant_test.tem_out_loc1    30.15
# plant_test.hum_out_loc1       37
# Name: 901, dtype: object
# plant_test.tem_in          31.06
# plant_test.hum_in          35.35
# plant_test.tem_coil         29.9
# plant_test.tem_out_loc1    29.75
# plant_test.hum_out_loc1    38.77
# Name: 902, dtype: object
